# %%
import sys
sys.path.append('C:/Users/Manhab Zafar/Desktop/CNET-Iteration-2/src')
from data_preprocessing import DataPreprocessor

# Initialize preprocessor
preprocessor = DataPreprocessor(sequence_length=10)

# Prepare data
data = preprocessor.prepare_data(
    filepath='C:/Users/Manhab Zafar/Desktop/CNET-Iteration-2/data/raw/InSDN_Normal_and_Attack_Combined.csv',
    test_size=0.3,
    random_state=42
)

# Save preprocessed data
import pickle
with open('C:/Users/Manhab Zafar/Desktop/CNET-Iteration-2/data/processed/preprocessed_data.pkl', 'wb') as f:
    pickle.dump(data, f)

print("✅ Preprocessing complete! Data saved.")
# Out:
# ...
# STARTING PREPROCESSING PIPELINE
# ...
# Loaded dataset with shape: (205167, 84)
# Data shape before cleaning: (205167, 84)
# Data shape after cleaning: (205167, 84)
# Normal samples: 68424
# Attack samples: 136743
# Selected 79 features
# Selected 79 features
#
# Creating sequences with length 10...
#
# ...
# PREPROCESSING COMPLETE
# ...
# Training data shape: (47887, 10, 79)
# Validation data shape: (157253, 10, 79)
# Number of features: 79
# Sequence length: 10
# ✅ Preprocessing complete! Data saved.
